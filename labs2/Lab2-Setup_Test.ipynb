# %% [markdown]
# # Mobile sensing Lab 2 - Python framework for data processing

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import signal
from sklearn.tree import DecisionTreeClassifier
print('Success')
# Out:
# Success

# %%
import os
data_path = os.getcwd()+"/data/motion-sense-processed.csv"
df = pd.read_csv(data_path)

# %%
df
# Out:
#          Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                 0       1.528132       -0.733896      0.696372   0.741895
# 1                 1       1.527992       -0.716987      0.677762   0.753099
# 2                 2       1.527765       -0.706999      0.670951   0.759611
# 3                 3       1.516768       -0.704678      0.675735   0.760709
# 4                 4       1.493941       -0.703918      0.672994   0.760062
# ...             ...            ...             ...           ...        ...
# 1412860     1412860      -2.368280       -0.381075     -0.089417  -0.648402
# 1412861     1412861      -2.368752       -0.381071     -0.089478  -0.648090
# 1412862     1412862      -2.369130       -0.381163     -0.089465  -0.647814
# 1412863     1412863      -2.369372       -0.381295     -0.089468  -0.647619
# 1412864     1412864      -2.369404       -0.381297     -0.089545  -0.647598
#
# ...

# %%
print(f"Unique ids: {len(df.id.unique())}")
# Out:
# Unique ids: 24

# %%
print(f"Average age: {df.age.mean()}")
print(f"Standard dev: {df.age.std()}")
# Out:
# Average age: 28.832020752159618
# Standard dev: 5.303462687553288

# %%
df_agg = df.groupby('id').mean()
df_agg
# Out:
#       Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# id
# 0.0      31155.5       0.206307       -0.867166      0.545989   0.118094
# 1.0      93481.0       0.958013       -0.879242      0.258318   0.265337
# 2.0     155927.0       0.935801       -1.105530     -0.091239   0.262779
# 3.0     215236.5      -0.562115       -1.118347     -0.495977   0.068748
# 4.0     269411.0      -1.162863       -0.905299      0.095983  -0.171378
# 5.0     324216.5      -0.464942       -1.024897     -0.259495   0.022187
# 6.0     383518.5       0.227899       -0.964709     -0.976021   0.187387
# 7.0     444520.0       0.429300       -1.111145      0.150577   0.175236
# 8.0     503451.5      -0.282596       -1.011880     -0.629428   0.096238
# 9.0     561917.5       0.618291       -0.735476     -0.421073   0.385587
# 10.0    621461.5      -0.808939       -0.987978      0.102673  -0.084645
# 11.0    677754.0      -0.700159       -1.075498     -0.585344  -0.017625
# ...

# %%
df[df_agg.gender == 0].age.mean()
# Out:
# /Users/erikjanezic/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-19-95c668e42024> in <module>
# ----> 1 df[df_agg.gender == 0].age.mean()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2969         # Do we have a (boolean) 1d indexer?
#    2970         if com.is_bool_indexer(key):
# -> 2971             return self._getitem_bool_array(key)
#    2972
#    2973         # We are left with two options: a single key, and a collection of keys,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3021         # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
m_average_age = df_agg[df_agg.gender == 0].age.mean()
f_average_age = df_agg[df_agg.gender == 1].age.mean()
print(f"Males:{m_average_age}")
print(f"Females:{f_average_age}")
# Out:
# Males:26.2
# Females:30.642857142857142

# %%
x_amp = df['userAcceleration.x']
y_amp = df['userAcceleration.y']
z_amp = df['userAcceleration.z']
amplitude = np.sqrt(x_amp**2+y_amp**2+z_amp**2)
amplitude
df['accMagnitude']=amplitude
df
# Out:
#          Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0                 0       1.528132       -0.733896      0.696372   0.741895
# 1                 1       1.527992       -0.716987      0.677762   0.753099
# 2                 2       1.527765       -0.706999      0.670951   0.759611
# 3                 3       1.516768       -0.704678      0.675735   0.760709
# 4                 4       1.493941       -0.703918      0.672994   0.760062
# ...             ...            ...             ...           ...        ...
# 1412860     1412860      -2.368280       -0.381075     -0.089417  -0.648402
# 1412861     1412861      -2.368752       -0.381071     -0.089478  -0.648090
# 1412862     1412862      -2.369130       -0.381163     -0.089465  -0.647814
# 1412863     1412863      -2.369372       -0.381295     -0.089468  -0.647619
# 1412864     1412864      -2.369404       -0.381297     -0.089545  -0.647598
#
# ...

# %%
def filter_extract():
